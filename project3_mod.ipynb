# %%
import numpy as np
import pandas as pd
import datetime
from datetime import timedelta

offer = pd.read_csv("C:/Users/aryij/Documents/AI Bootcamp/Section 3/project3/db_csv/departure_mod_2.csv")
prediction = pd.read_csv("C:/Users/aryij/Documents/AI Bootcamp/Section 3/project3/db_csv/prediction_mod.csv")

# %%
offer.head()
# Out:
#    number  seg_id_1 code total_dur     dur_1 iatacode_1 iatacode_2  \
# 0     1.0      61.0  789  PT14H20M  PT11H15M        ICN        AMS
# 1     2.0     170.0  789  PT14H45M  PT11H15M        ICN        AMS
# 2     3.0      51.0  789  PT15H15M  PT11H15M        ICN        AMS
# 3     4.0     200.0  789  PT15H55M  PT11H15M        ICN        AMS
# 4     5.0       1.0  772     PT16H  PT11H35M        ICN        AMS
#
#   carriercode_1  air_number_1        at_1  ... seg_id_1.1  dur_2 iatacode_1.1  \
# 0            KL         856.0  2022-07-01  ...       61.0   PT2H          AMS
# 1            KL         856.0  2022-07-01  ...      170.0    NaN          AMS
# 2            KL         856.0  2022-07-01  ...       51.0    NaN          AMS
# 3            KL         856.0  2022-07-01  ...      200.0    NaN          AMS
# 4            KL          79.0  2022-07-01  ...        1.0    NaN          AMS
#
#   iatacode_2.1 carriercode_2 air_number_2        at_2 bookable_seats  \
# 0          LCY            KL        981.0  2022-07-01            9.0
# 1          LHR            KL       1001.0  2022-07-01            9.0
# 2          LCY            KL        983.0  2022-07-01            9.0
# 3          LCY            KL        985.0  2022-07-01            9.0
# 4          LCY            KL        981.0  2022-07-01            9.0
#
#    currency   total
# 0       EUR  447.44
# 1       EUR  447.44
# 2       EUR  447.44
# 3       EUR  447.44
# 4       EUR  447.44
#
# [5 rows x 21 columns]

# %%
prediction.head()
# Out:
#    id dest        date  ontime_proba  number
# 0   1  LON  2022-07-01      0.821371       1
# 1   2  LON  2022-07-02      0.818650       2
# 2   3  LON  2022-07-03      0.797806       3
# 3   4  LON  2022-07-04      0.753250       4
# 4   5  LON  2022-07-05      0.807903       5

# %%
prediction["dest"].value_counts()
# Out:
# LON    31
# PAR    31
# MAD    31
# FRA    31
# ROM    31
# Name: dest, dtype: int64

# %%
offer["iatacode_2.1"].value_counts()
# Out:
# LHR    2768
# CDG    2407
# FCO    2056
# FRA    1810
# MAD    1732
# LCY     289
# LGW     225
# STN      30
# ORY       1
# Name: iatacode_2.1, dtype: int64

# %%
def country(x):
    if x == "FRA":
        return "FRA"
    elif x == "FCO":
        return "ROM"
    elif x == "MAD":
        return "MAD"
    elif x == "CDG" or x == "ORY":
        return "PAR"
    elif x == "STN" or x == "LGW" or x == "LCY" or x == "LHR":
        return "LON"

# %%
offer["dest"] = offer["iatacode_2.1"].apply(lambda x : country(x))

# %%
offer["dest_2"] = offer["iatacode_1.1"].apply(lambda x : country(x))

# %%
offer.head()
# Out:
#    number  seg_id_1 code total_dur     dur_1 iatacode_1 iatacode_2  \
# 0     1.0      61.0  789  PT14H20M  PT11H15M        ICN        AMS
# 1     2.0     170.0  789  PT14H45M  PT11H15M        ICN        AMS
# 2     3.0      51.0  789  PT15H15M  PT11H15M        ICN        AMS
# 3     4.0     200.0  789  PT15H55M  PT11H15M        ICN        AMS
# 4     5.0       1.0  772     PT16H  PT11H35M        ICN        AMS
#
#   carriercode_1  air_number_1        at_1  ... iatacode_1.1  iatacode_2.1  \
# 0            KL         856.0  2022-07-01  ...          AMS           LCY
# 1            KL         856.0  2022-07-01  ...          AMS           LHR
# 2            KL         856.0  2022-07-01  ...          AMS           LCY
# 3            KL         856.0  2022-07-01  ...          AMS           LCY
# 4            KL          79.0  2022-07-01  ...          AMS           LCY
#
#   carriercode_2 air_number_2        at_2 bookable_seats  currency   total  \
# 0            KL        981.0  2022-07-01            9.0       EUR  447.44
# 1            KL       1001.0  2022-07-01            9.0       EUR  447.44
# 2            KL        983.0  2022-07-01            9.0       EUR  447.44
# 3            KL        985.0  2022-07-01            9.0       EUR  447.44
# 4            KL        981.0  2022-07-01            9.0       EUR  447.44
#
#    dest dest_2
# 0   LON   None
# 1   LON   None
# 2   LON   None
# 3   LON   None
# 4   LON   None
#
# [5 rows x 23 columns]

# %%
offer["dest"] = offer["dest"].fillna(offer["dest_2"])

# %%
offer = offer.drop(columns=["dest_2"], axis=1)

# %%
offer["arr_date"] = offer["at_2"]
offer["arr_date_2"] = offer["at_1"]

# %%
offer["arr_date"] = offer["arr_date"].fillna(offer["arr_date_2"])

# %%
offer = offer.drop(columns=["arr_date_2"], axis=1)

# %%
offer.head()
# Out:
#    number  seg_id_1 code total_dur     dur_1 iatacode_1 iatacode_2  \
# 0     1.0      61.0  789  PT14H20M  PT11H15M        ICN        AMS
# 1     2.0     170.0  789  PT14H45M  PT11H15M        ICN        AMS
# 2     3.0      51.0  789  PT15H15M  PT11H15M        ICN        AMS
# 3     4.0     200.0  789  PT15H55M  PT11H15M        ICN        AMS
# 4     5.0       1.0  772     PT16H  PT11H35M        ICN        AMS
#
#   carriercode_1  air_number_1        at_1  ... iatacode_1.1  iatacode_2.1  \
# 0            KL         856.0  2022-07-01  ...          AMS           LCY
# 1            KL         856.0  2022-07-01  ...          AMS           LHR
# 2            KL         856.0  2022-07-01  ...          AMS           LCY
# 3            KL         856.0  2022-07-01  ...          AMS           LCY
# 4            KL          79.0  2022-07-01  ...          AMS           LCY
#
#   carriercode_2 air_number_2        at_2 bookable_seats  currency   total  \
# 0            KL        981.0  2022-07-01            9.0       EUR  447.44
# 1            KL       1001.0  2022-07-01            9.0       EUR  447.44
# 2            KL        983.0  2022-07-01            9.0       EUR  447.44
# 3            KL        985.0  2022-07-01            9.0       EUR  447.44
# 4            KL        981.0  2022-07-01            9.0       EUR  447.44
#
#    dest    arr_date
# 0   LON  2022-07-01
# 1   LON  2022-07-01
# 2   LON  2022-07-01
# 3   LON  2022-07-01
# 4   LON  2022-07-01
#
# [5 rows x 23 columns]

# %%
prediction = prediction.drop(columns=["id", "number"], axis=1)

# %%
prediction.rename(columns={"date" : "arr_date"}, inplace=True)

# %%
prediction.head()
# Out:
#   dest    arr_date  ontime_proba
# 0  LON  2022-07-01      0.821371
# 1  LON  2022-07-02      0.818650
# 2  LON  2022-07-03      0.797806
# 3  LON  2022-07-04      0.753250
# 4  LON  2022-07-05      0.807903

# %%
offer = pd.merge(left=offer, right=prediction)

# %%
# offer = pd.merge(left=offer, right=prediction, how="left", on=["dest", "arr_date"])

# %%
offer
# Out:
#         number  seg_id_1 code total_dur     dur_1 iatacode_1 iatacode_2  \
# 0          1.0      61.0  789  PT14H20M  PT11H15M        ICN        AMS
# 1          2.0     170.0  789  PT14H45M  PT11H15M        ICN        AMS
# 2          3.0      51.0  789  PT15H15M  PT11H15M        ICN        AMS
# 3          4.0     200.0  789  PT15H55M  PT11H15M        ICN        AMS
# 4          5.0       1.0  772     PT16H  PT11H35M        ICN        AMS
# ...        ...       ...  ...       ...       ...        ...        ...
# 11426  12056.0     102.0  77W  PT15H40M  PT11H50M        ICN        VIE
# 11427  12059.0      88.0  744  PT15H35M  PT11H25M        ICN        VIE
# 11428  12060.0       3.0  744     PT16H  PT11H25M        ICN        VIE
# 11429  12062.0       7.0  388     PT18H  PT11H30M        ICN        WAW
# 11430  12064.0      25.0  333   PT21H5M      PT9H        ICN        ZRH
#
#       carriercode_1  air_number_1        at_1  ... iatacode_2.1  \
# 0                KL         856.0  2022-07-01  ...          LCY
# 1                KL         856.0  2022-07-01  ...          LHR
# 2                KL         856.0  2022-07-01  ...          LCY
# 3                KL         856.0  2022-07-01  ...          LCY
# 4                KL          79.0  2022-07-01  ...          LCY
# ...             ...           ...         ...  ...          ...
# 11426            KE         925.0  2022-07-31  ...          FCO
# 11427            6X        9745.0  2022-07-31  ...          FCO
# 11428            6X        9745.0  2022-07-31  ...          FCO
# 11429            OZ         541.0  2022-07-31  ...          FCO
# 11430            OZ         767.0  2022-07-31  ...          FCO
#
#        carriercode_2 air_number_2        at_2 bookable_seats currency  \
# 0                 KL        981.0  2022-07-01            9.0      EUR
# 1                 KL       1001.0  2022-07-01            9.0      EUR
# 2                 KL        983.0  2022-07-01            9.0      EUR
# 3                 KL        985.0  2022-07-01            9.0      EUR
# 4                 KL        981.0  2022-07-01            9.0      EUR
# ...              ...          ...         ...            ...      ...
# 11426             KL       1609.0  2022-07-31            9.0      EUR
# 11427             LH       4373.0  2022-07-31            9.0      EUR
# 11428             LH        242.0  2022-07-31            9.0      EUR
# 11429             LH       4373.0  2022-07-31            9.0      EUR
# 11430             AI        123.0  2022-07-31            9.0      EUR
#
#          total dest    arr_date ontime_proba
# 0       447.44  LON  2022-07-01     0.821371
# 1       447.44  LON  2022-07-01     0.821371
# 2       447.44  LON  2022-07-01     0.821371
# 3       447.44  LON  2022-07-01     0.821371
# 4       447.44  LON  2022-07-01     0.821371
# ...        ...  ...         ...          ...
# 11426  1222.66  ROM  2022-07-31     0.786006
# 11427  1529.13  ROM  2022-07-31     0.786006
# 11428  1529.13  ROM  2022-07-31     0.786006
# 11429  2078.73  ROM  2022-07-31     0.786006
# 11430  2730.08  ROM  2022-07-31     0.786006
#
# [11431 rows x 24 columns]

# %%
offer = offer.drop(columns=["number", "seg_id_1", "seg_id_1.1", "air_number_1", 'air_number_2', 'at_2'])

# %%
offer.columns
# Out:
# Index(['code', 'total_dur', 'dur_1', 'iatacode_1', 'iatacode_2',
#        'carriercode_1', 'at_1', 'transfer', 'dur_2', 'iatacode_1.1',
#        'iatacode_2.1', 'carriercode_2', 'bookable_seats', 'currency', 'total',
#        'dest', 'arr_date', 'ontime_proba'],
#       dtype='object')

# %%
offer.columns = ['code', 'total_dur', 'dur_1', "departure_1", "arrival_1", 'carriercode_1', "dep_date", 'transfer', 'dur_2',
                 "departure_2", "arrival_2", 'carriercode_2', 'bookable_seats', 'currency', 'total', 'dest', 'arr_date', 'ontime_proba']

# %%
offer = offer[['code', 'total_dur', 'dur_1', "departure_1", "arrival_1", 'carriercode_1', "dep_date", 'transfer', 'dur_2',
                 "departure_2", "arrival_2", 'carriercode_2', 'arr_date', 'bookable_seats', 'currency', 'total', 'dest', 'ontime_proba']]

# %%
# "departure_1", "dep_date", "transfer" category로 형변환
offer["departure_1"] = offer["departure_1"].astype("category")
offer["dep_date"] = offer["dep_date"].astype("category")
offer["transfer"] = offer["transfer"].astype("category")

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(offer, train_size=0.8, random_state=42)

# %%
train, val = train_test_split(train, train_size=0.8, random_state=42)

# %%
train.shape, val.shape, test.shape
# Out:
# ((7315, 18), (1829, 18), (2287, 18))

# %%
target = "total"
features = ["departure_1", "dep_date", "transfer"]
# features = offer.drop(columns=[target]).columns

# %%
X_train = train[features]
y_train = train[target]

X_val = val[features]
y_val = val[target]

X_test = test[features]
y_test = test[target]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((7315, 3), (7315,), (1829, 3), (1829,), (2287, 3), (2287,))

# %%
# 회귀 기준모델 생성
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt

# 기준 예측값
predicted = y_train.mean()
y_pred_base = [predicted] * len(y_val)

mae_base = mean_absolute_error(y_val, y_pred_base)
mse_base = mean_squared_error(y_val, y_pred_base)
rmse_base = sqrt(mse_base)
r2_base = r2_score(y_val, y_pred_base)

print("기준 모델 (평균) :", predicted)
print("기준 모델 MAE :", mae_base)
print("기준 모델 MSE :", mse_base)
print("기준 모델 RMSE :", rmse_base)
print("기준 모델 R2 score :", r2_base)
# Out:
# 기준 모델 (평균) : 1162.4968366370472
# 기준 모델 MAE : 820.3186950553978
# 기준 모델 MSE : 2210148.780095134
# 기준 모델 RMSE : 1486.656914050829
# 기준 모델 R2 score : -0.0004737774383678506

# %%
pip install category-encoders
# Out:
# Requirement already satisfied: category-encoders in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (2.4.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from category-encoders) (0.5.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from category-encoders) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from category-encoders) (1.0.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from category-encoders) (0.13.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from category-encoders) (1.7.3)
# Requirement already satisfied: pandas>=0.21.1 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from category-encoders) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.21.1->category-encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.21.1->category-encoders) (2022.1)
# Requirement already satisfied: six in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from patsy>=0.5.1->category-encoders) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->category-encoders) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->category-encoders) (3.0.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from statsmodels>=0.9.0->category-encoders) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aryij\appdata\local\programs\python\python310\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->category-encoders) (3.0.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\aryij\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# 그래디언트 부스팅으로 회귀 계산

from xgboost import XGBRegressor
from category_encoders import OrdinalEncoder

encoder = OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)
X_test_encoded = encoder.transform(X_test)

# %%
boosting = XGBRegressor(
    n_estimators=1000,
    objective="reg:squarederror",
    learning_rate=0.2,
    n_jobs=-1
)

eval_set = [(X_train_encoded, y_train),
            (X_val_encoded, y_val)]

boosting.fit(X_train_encoded, y_train,
             eval_set=eval_set,
             early_stopping_rounds=100)
# Out:
# [0]	validation_0-rmse:1813.52004	validation_1-rmse:1736.60275
# [1]	validation_0-rmse:1724.81881	validation_1-rmse:1648.89457
# [2]	validation_0-rmse:1665.44160	validation_1-rmse:1590.96451
# [3]	validation_0-rmse:1626.18520	validation_1-rmse:1553.16390
# [4]	validation_0-rmse:1600.50016	validation_1-rmse:1529.02780
# [5]	validation_0-rmse:1583.76864	validation_1-rmse:1513.78900
# [6]	validation_0-rmse:1572.88856	validation_1-rmse:1503.87586
# [7]	validation_0-rmse:1565.88700	validation_1-rmse:1497.71625
# [8]	validation_0-rmse:1561.29826	validation_1-rmse:1494.25332
# [9]	validation_0-rmse:1558.33027	validation_1-rmse:1492.19296
# [10]	validation_0-rmse:1556.42351	validation_1-rmse:1491.02063
# [11]	validation_0-rmse:1555.19877	validation_1-rmse:1490.39936
# [12]	validation_0-rmse:1554.40229	validation_1-rmse:1490.07817
# c:\Users\aryij\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [13]	validation_0-rmse:1553.89097	validation_1-rmse:1489.95527
# [14]	validation_0-rmse:1553.53895	validation_1-rmse:1489.91978
# [15]	validation_0-rmse:1553.31936	validation_1-rmse:1489.96176
# [16]	validation_0-rmse:1553.18158	validation_1-rmse:1490.01196
# [17]	validation_0-rmse:1553.08477	validation_1-rmse:1490.12996
# [18]	validation_0-rmse:1553.02334	validation_1-rmse:1490.22526
# [19]	validation_0-rmse:1552.98305	validation_1-rmse:1490.30966
# [20]	validation_0-rmse:1552.95896	validation_1-rmse:1490.36673
# [21]	validation_0-rmse:1552.93655	validation_1-rmse:1490.47611
# [22]	validation_0-rmse:1552.92146	validation_1-rmse:1490.56111
# [23]	validation_0-rmse:1552.91113	validation_1-rmse:1490.63949
# [24]	validation_0-rmse:1552.90582	validation_1-rmse:1490.67845
# [25]	validation_0-rmse:1552.90017	validation_1-rmse:1490.74331
# [69]	validation_0-rmse:1552.84218	validation_1-rmse:1491.18659
# [70]	validation_0-rmse:1552.84206	validation_1-rmse:1491.18658
# [71]	validation_0-rmse:1552.84190	validation_1-rmse:1491.18898
# [72]	validation_0-rmse:1552.84182	validation_1-rmse:1491.19090
# [73]	validation_0-rmse:1552.84175	validation_1-rmse:1491.19208
# [74]	validation_0-rmse:1552.84171	validation_1-rmse:1491.19307
# [75]	validation_0-rmse:1552.84170	validation_1-rmse:1491.19266
# [76]	validation_0-rmse:1552.84167	validation_1-rmse:1491.19325
# [77]	validation_0-rmse:1552.84165	validation_1-rmse:1491.19401
# [78]	validation_0-rmse:1552.84164	validation_1-rmse:1491.19439
# [79]	validation_0-rmse:1552.84162	validation_1-rmse:1491.19540
# [80]	validation_0-rmse:1552.84161	validation_1-rmse:1491.19687
# [81]	validation_0-rmse:1552.84161	validation_1-rmse:1491.19717
# [82]	validation_0-rmse:1552.84161	validation_1-rmse:1491.19754
# [83]	validation_0-rmse:1552.84161	validation_1-rmse:1491.19771
# [84]	validation_0-rmse:1552.84160	validation_1-rmse:1491.19784
# [85]	validation_0-rmse:1552.84161	validation_1-rmse:1491.19849
# [86]	validation_0-rmse:1552.84158	validation_1-rmse:1491.19865
# [87]	validation_0-rmse:1552.84160	validation_1-rmse:1491.19924
# [88]	validation_0-rmse:1552.84157	validation_1-rmse:1491.20000
# [89]	validation_0-rmse:1552.84158	validation_1-rmse:1491.20047
# [90]	validation_0-rmse:1552.84159	validation_1-rmse:1491.20062
# [91]	validation_0-rmse:1552.84158	validation_1-rmse:1491.20122
# [92]	validation_0-rmse:1552.84157	validation_1-rmse:1491.20149
# [93]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20163
# [94]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20202
# [95]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20238
# [96]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20279
# [97]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20311
# [98]	validation_0-rmse:1552.84155	validation_1-rmse:1491.20326
# [99]	validation_0-rmse:1552.84157	validation_1-rmse:1491.20355
# [100]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20370
# [101]	validation_0-rmse:1552.84157	validation_1-rmse:1491.20392
# [102]	validation_0-rmse:1552.84157	validation_1-rmse:1491.20395
# [103]	validation_0-rmse:1552.84155	validation_1-rmse:1491.20375
# [104]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20397
# [105]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20409
# [106]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20408
# [107]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20417
# [108]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20405
# [109]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20414
# [110]	validation_0-rmse:1552.84155	validation_1-rmse:1491.20428
# [111]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20431
# [112]	validation_0-rmse:1552.84156	validation_1-rmse:1491.20434
# [113]	validation_0-rmse:1552.84157	validation_1-rmse:1491.20434
# [114]	validation_0-rmse:1552.84157	validation_1-rmse:1491.20437
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=-1, num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred_val_xgb = boosting.predict(X_val_encoded)
y_pred_test_xgb = boosting.predict(X_test_encoded)

print("XGB val MAE :", mean_absolute_error(y_val, y_pred_val_xgb))
print("XGB val MSE :", mean_squared_error(y_val, y_pred_val_xgb))
print("XGB val RMSE :", sqrt(mean_squared_error(y_val, y_pred_val_xgb)))
print("XGB val R2 score :", r2_score(y_val, y_pred_val_xgb))
# Out:
# XGB val MAE : 797.8209971415926
# XGB val MSE : 2219860.901701894
# XGB val RMSE : 1489.9197635114094
# XGB val R2 score : -0.004870188701884048

# %%
print("XGB MAE_test :", mean_absolute_error(y_test, y_pred_test_xgb))
print("XGB MSE_test :", mean_squared_error(y_test, y_pred_test_xgb))
print("XGB RMSE_test :", sqrt(mean_squared_error(y_test, y_pred_test_xgb)))
print("XGB R2 score_test :", r2_score(y_test, y_pred_test_xgb))
# Out:
# XGB MAE_test : 804.4623637157284
# XGB MSE_test : 2247865.390199225
# XGB RMSE_test : 1499.2882945581964
# XGB R2 score_test : -0.0085733167996771

# %%
# LightGBM 모델도 사용
from lightgbm import LGBMRegressor

# %%
lgbm = LGBMRegressor(n_estimators=100, learning_rate=0.2)

evals = [(X_train_encoded, y_train),
         (X_val_encoded, y_val)]

lgbm.fit(X_train_encoded, y_train, 
         eval_set=evals, 
         early_stopping_rounds=100)
# Out:
# [1]	training's l2: 2.42261e+06	valid_1's l2: 2.21046e+06
# [2]	training's l2: 2.41913e+06	valid_1's l2: 2.21142e+06
# [3]	training's l2: 2.41689e+06	valid_1's l2: 2.21272e+06
# [4]	training's l2: 2.41545e+06	valid_1's l2: 2.21426e+06
# [5]	training's l2: 2.41448e+06	valid_1's l2: 2.21553e+06
# [6]	training's l2: 2.41387e+06	valid_1's l2: 2.21671e+06
# [7]	training's l2: 2.41344e+06	valid_1's l2: 2.21767e+06
# [8]	training's l2: 2.41317e+06	valid_1's l2: 2.21865e+06
# [9]	training's l2: 2.41297e+06	valid_1's l2: 2.21928e+06
# [10]	training's l2: 2.41285e+06	valid_1's l2: 2.21987e+06
# [11]	training's l2: 2.41275e+06	valid_1's l2: 2.22034e+06
# [12]	training's l2: 2.41268e+06	valid_1's l2: 2.2208e+06
# [13]	training's l2: 2.41263e+06	valid_1's l2: 2.22101e+06
# [14]	training's l2: 2.41259e+06	valid_1's l2: 2.22133e+06
# [15]	training's l2: 2.41255e+06	valid_1's l2: 2.22165e+06
# [16]	training's l2: 2.41251e+06	valid_1's l2: 2.22181e+06
# [17]	training's l2: 2.41249e+06	valid_1's l2: 2.22201e+06
# [18]	training's l2: 2.41246e+06	valid_1's l2: 2.22213e+06
# [19]	training's l2: 2.41244e+06	valid_1's l2: 2.22231e+06
# [20]	training's l2: 2.41241e+06	valid_1's l2: 2.22242e+06
# [21]	training's l2: 2.41239e+06	valid_1's l2: 2.22248e+06
# [22]	training's l2: 2.41235e+06	valid_1's l2: 2.22249e+06
# [23]	training's l2: 2.41233e+06	valid_1's l2: 2.22259e+06
# [24]	training's l2: 2.41231e+06	valid_1's l2: 2.22269e+06
# [25]	training's l2: 2.4123e+06	valid_1's l2: 2.22276e+06
# [26]	training's l2: 2.41226e+06	valid_1's l2: 2.22277e+06
# [27]	training's l2: 2.41225e+06	valid_1's l2: 2.22277e+06
# [28]	training's l2: 2.41223e+06	valid_1's l2: 2.22286e+06
# [71]	training's l2: 2.41176e+06	valid_1's l2: 2.22328e+06
# [72]	training's l2: 2.41176e+06	valid_1's l2: 2.2233e+06
# [73]	training's l2: 2.41175e+06	valid_1's l2: 2.22331e+06
# [74]	training's l2: 2.41175e+06	valid_1's l2: 2.2233e+06
# [75]	training's l2: 2.41174e+06	valid_1's l2: 2.22332e+06
# [76]	training's l2: 2.41174e+06	valid_1's l2: 2.22337e+06
# [77]	training's l2: 2.41172e+06	valid_1's l2: 2.22333e+06
# [78]	training's l2: 2.41172e+06	valid_1's l2: 2.22332e+06
# [79]	training's l2: 2.41172e+06	valid_1's l2: 2.22334e+06
# [80]	training's l2: 2.41171e+06	valid_1's l2: 2.22335e+06
# [81]	training's l2: 2.4117e+06	valid_1's l2: 2.22336e+06
# [82]	training's l2: 2.41169e+06	valid_1's l2: 2.22331e+06
# [83]	training's l2: 2.41169e+06	valid_1's l2: 2.22331e+06
# [84]	training's l2: 2.41168e+06	valid_1's l2: 2.22334e+06
# [85]	training's l2: 2.41168e+06	valid_1's l2: 2.22335e+06
# [86]	training's l2: 2.41168e+06	valid_1's l2: 2.22338e+06
# [87]	training's l2: 2.41167e+06	valid_1's l2: 2.22335e+06
# [88]	training's l2: 2.41166e+06	valid_1's l2: 2.22335e+06
# [89]	training's l2: 2.41166e+06	valid_1's l2: 2.22336e+06
# [90]	training's l2: 2.41166e+06	valid_1's l2: 2.22337e+06
# [91]	training's l2: 2.41165e+06	valid_1's l2: 2.22341e+06
# [92]	training's l2: 2.41165e+06	valid_1's l2: 2.22341e+06
# [93]	training's l2: 2.41165e+06	valid_1's l2: 2.22342e+06
# [94]	training's l2: 2.41164e+06	valid_1's l2: 2.22338e+06
# [95]	training's l2: 2.41163e+06	valid_1's l2: 2.22338e+06
# [96]	training's l2: 2.41163e+06	valid_1's l2: 2.22339e+06
# [97]	training's l2: 2.41163e+06	valid_1's l2: 2.2234e+06
# [98]	training's l2: 2.41163e+06	valid_1's l2: 2.22342e+06
# [99]	training's l2: 2.41162e+06	valid_1's l2: 2.22339e+06
# [100]	training's l2: 2.41161e+06	valid_1's l2: 2.22339e+06
# c:\Users\aryij\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# LGBMRegressor(learning_rate=0.2)

# %%
y_pred_val_xgb = lgbm.predict(X_val_encoded)
y_pred_test_xgb = lgbm.predict(X_test_encoded)

print("XGB val MAE :", mean_absolute_error(y_val, y_pred_val_xgb))
print("XGB val MSE :", mean_squared_error(y_val, y_pred_val_xgb))
print("XGB val RMSE :", sqrt(mean_squared_error(y_val, y_pred_val_xgb)))
print("XGB val R2 score :", r2_score(y_val, y_pred_val_xgb))
# Out:
# XGB val MAE : 822.8831823179139
# XGB val MSE : 2223389.103117843
# XGB val RMSE : 1491.103317385433
# XGB val R2 score : -0.006467308782653447

# %%
boosting.save_model("xgb_model.model")

# %%
lgbm.booster_.save_model("lgbm_model.model")
